# %% [markdown]
# Categorical Plots

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = sns.load_dataset('tips')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df['sex'].unique()
# Out:
# ['Female', 'Male']
# Categories (2, object): ['Male', 'Female']

# %%
sns.countplot(x=df['smoker'], hue=df['sex'])
# Out:
# <Axes: xlabel='smoker', ylabel='count'>

# %% [markdown]
# Bar Plot

# %%
sns.barplot(x=df['sex'], y=df['total_bill'] , palette='rainbow')
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_20112\4034258920.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=df['sex'], y=df['total_bill'] , palette='rainbow')
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
import numpy as np
sns.barplot(x=df['sex'], y=df['tip'] , palette='rainbow', estimator=np.sum)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_20112\1925537452.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=df['sex'], y=df['tip'] , palette='rainbow', estimator=np.sum)
# <Axes: xlabel='sex', ylabel='tip'>

# %% [markdown]
# Box Plot

# %%
sns.boxplot(x=df['day'], y=df['tip'], data=df, palette='rainbow')
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_20112\2961942479.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=df['day'], y=df['tip'], data=df, palette='rainbow')
# <Axes: xlabel='day', ylabel='tip'>

# %% [markdown]
# Voilin Plot

# %%
sns.violinplot(x=df['smoker'], y=df['day'], palette='rainbow')
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_20112\3546875735.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x=df['smoker'], y=df['day'], palette='rainbow')
# <Axes: xlabel='smoker', ylabel='day'>

# %% [markdown]
# Strip Plot --> Shows a scatterplot, one variable is categorical

# %%
sns.stripplot(x='day', y='total_bill', data=df, palette='rainbow')
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_20112\1478037909.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.stripplot(x='day', y='total_bill', data=df, palette='rainbow')
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# Swarm Plot

# %%
sns.swarmplot(x='day', y='total_bill', data=df)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# Combining Swarmplot and Violin Plot

# %%
sns.violinplot(x='tip', y='day', data=df, palette='rainbow')
sns.swarmplot(x='tip', y='day', data=df,)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_20112\2634826892.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='tip', y='day', data=df, palette='rainbow')
# d:\Python\.venv\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 9.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# d:\Python\.venv\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 10.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# d:\Python\.venv\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 5.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...
